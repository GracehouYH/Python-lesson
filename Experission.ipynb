# %%
import urllib.request
import pandas as pd
import seaborn as  sns

# %%
source_url = "https://raw.githubusercontent.com/foerstner-lab/Bits_and_pieces_for_the_carpentries_workshops/master/text_file_examples/Expression_comparison.csv"
table_file = "Expression_comparison.csv"

# %%
urllib.request.urlretrieve(source_url, table_file)
# Out:
# ('Expression_comparison.csv', <http.client.HTTPMessage at 0x14f22b9c2c8>)

# %%
comparison = pd.read_csv(table_file, sep="\t", comment="#", header=0)

# %%
comparison
# Out:
#     Gene  Comparison_B_to_A  Comparison_C_to_A  Comparison_D_to_A  \
# 0   thrL              -0.50               0.00             0.1000
# 1   thrA              -1.20               0.10             0.1000
# 2   thrB               2.00               0.10            -2.5000
# 3   thrC               0.00               0.10             0.1000
# 4   yaaX               0.10               0.71             0.3000
# 5   yaaA               0.10               0.90             0.1000
# 6   yaaJ              -0.10              -0.50            -1.1000
# 7   talB               0.71              -0.10             0.1000
# 8    mog               0.23               0.70             0.7100
# 9   satP               0.40              -0.10             0.4000
# 10  yaaW               0.30               0.30             0.1000
# 11  mbiA               0.01              -0.10            -0.5000
# 12  yaaI               2.40               0.31             0.1000
# 13  dnaK               0.01               0.80             0.6000
# 14  dnaJ               0.23               0.01             0.3737
#
#     Comparison_E_to_A
# 0                0.10
# 1                0.71
# 2                0.40
# 3                0.10
# 4                0.10
# 5               -0.50
# 6                0.30
# 7               -0.10
# 8                0.10
# 9                0.71
# 10               0.10
# 11               0.10
# 12               0.40
# 13               2.50
# 14               0.30

# %%
comparison.set_index("Gene", inplace=True)

# %%
comparison
# Out:
#       Comparison_B_to_A  Comparison_C_to_A  Comparison_D_to_A  \
# Gene
# thrL              -0.50               0.00             0.1000
# thrA              -1.20               0.10             0.1000
# thrB               2.00               0.10            -2.5000
# thrC               0.00               0.10             0.1000
# yaaX               0.10               0.71             0.3000
# yaaA               0.10               0.90             0.1000
# yaaJ              -0.10              -0.50            -1.1000
# talB               0.71              -0.10             0.1000
# mog                0.23               0.70             0.7100
# satP               0.40              -0.10             0.4000
# yaaW               0.30               0.30             0.1000
# mbiA               0.01              -0.10            -0.5000
# yaaI               2.40               0.31             0.1000
# dnaK               0.01               0.80             0.6000
# dnaJ               0.23               0.01             0.3737
#
#       Comparison_E_to_A
# Gene
# thrL               0.10
# thrA               0.71
# thrB               0.40
# thrC               0.10
# yaaX               0.10
# yaaA              -0.50
# yaaJ               0.30
# talB              -0.10
# mog                0.10
# satP               0.71
# yaaW               0.10
# mbiA               0.10
# yaaI               0.40
# dnaK               2.50
# dnaJ               0.30

# %%
# %matplotlib inline
sns.heatmap(comparison)

# %%
sns.heatmap(comparison, annot=True)

# %%
sns.clustermap(comparison, camp="YlGnBu",annot=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-cca42b2e75ca> in <module>
# ----> 1 sns.clustermap(comparison, camp="YlGnBu",annot=True)
#
# ~\Anaconda3\lib\site-packages\seaborn\matrix.py in clustermap(data, pivot_kws, method, metric, z_score, standard_scale, figsize, cbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, row_colors, col_colors, mask, **kwargs)
#    1299                         row_cluster=row_cluster, col_cluster=col_cluster,
#    1300                         row_linkage=row_linkage, col_linkage=col_linkage,
# -> 1301                         **kwargs)
#
# ~\Anaconda3\lib\site-packages\seaborn\matrix.py in plot(self, metric, method, colorbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, **kws)
#    1137
#    1138         self.plot_colors(xind, yind, **kws)
# -> 1139         self.plot_matrix(colorbar_kws, xind, yind, **kws)
#    1140         return self
#    1141
#
# ~\Anaconda3\lib\site-packages\seaborn\matrix.py in plot_matrix(self, colorbar_kws, xind, yind, **kws)
#    1112         heatmap(self.data2d, ax=self.ax_heatmap, cbar_ax=self.cax,
#    1113                 cbar_kws=colorbar_kws, mask=self.mask,
# -> 1114                 xticklabels=xtl, yticklabels=ytl, **kws)
#    1115
#    1116         ytl = self.ax_heatmap.get_yticklabels()
#
# ~\Anaconda3\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     526     if square:
#     527         ax.set_aspect("equal")
# --> 528     plotter.plot(ax, cbar_ax, kwargs)
#     529     return ax
#     530
#
# ~\Anaconda3\lib\site-packages\seaborn\matrix.py in plot(self, ax, cax, kws)
#     282         # Draw the heatmap
#     283         mesh = ax.pcolormesh(self.plot_data, vmin=self.vmin, vmax=self.vmax,
# --> 284                              cmap=self.cmap, **kws)
#     285
#     286         # Set the axis limits
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in pcolormesh(self, alpha, norm, cmap, vmin, vmax, shading, antialiased, *args, **kwargs)
#    6169         collection = mcoll.QuadMesh(Nx - 1, Ny - 1, coords,
#    6170                                     antialiased=antialiased, shading=shading,
# -> 6171                                     **kwargs)
#    6172         collection.set_alpha(alpha)
#    6173         collection.set_array(C)
#
# ~\Anaconda3\lib\site-packages\matplotlib\collections.py in __init__(self, meshWidth, meshHeight, coordinates, antialiased, shading, **kwargs)
#    1910     def __init__(self, meshWidth, meshHeight, coordinates,
#    1911                  antialiased=True, shading='flat', **kwargs):
# -> 1912         Collection.__init__(self, **kwargs)
#    1913         self._meshWidth = meshWidth
#    1914         self._meshHeight = meshHeight
#
# ~\Anaconda3\lib\site-packages\matplotlib\collections.py in __init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, offset_position, zorder, **kwargs)
#     160
#     161         self._path_effects = None
# --> 162         self.update(kwargs)
#     163         self._paths = None
#     164
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
# --> 974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#     976         if len(ret):
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in <listcomp>(.0)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
# --> 974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#     976         if len(ret):
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in _update_property(self, k, v)
#     968                 if not callable(func):
#     969                     raise AttributeError('{!r} object has no property {!r}'
# --> 970                                          .format(type(self).__name__, k))
#     971                 return func(v)
#     972
#
# AttributeError: 'QuadMesh' object has no property 'camp'

# %%
sns.clustermap(comparison, camp="YlGnBu",annot=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-cca42b2e75ca> in <module>
# ----> 1 sns.clustermap(comparison, camp="YlGnBu",annot=True)
#
# ~\Anaconda3\lib\site-packages\seaborn\matrix.py in clustermap(data, pivot_kws, method, metric, z_score, standard_scale, figsize, cbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, row_colors, col_colors, mask, **kwargs)
#    1299                         row_cluster=row_cluster, col_cluster=col_cluster,
#    1300                         row_linkage=row_linkage, col_linkage=col_linkage,
# -> 1301                         **kwargs)
#
# ~\Anaconda3\lib\site-packages\seaborn\matrix.py in plot(self, metric, method, colorbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, **kws)
#    1137
#    1138         self.plot_colors(xind, yind, **kws)
# -> 1139         self.plot_matrix(colorbar_kws, xind, yind, **kws)
#    1140         return self
#    1141
#
# ~\Anaconda3\lib\site-packages\seaborn\matrix.py in plot_matrix(self, colorbar_kws, xind, yind, **kws)
#    1112         heatmap(self.data2d, ax=self.ax_heatmap, cbar_ax=self.cax,
#    1113                 cbar_kws=colorbar_kws, mask=self.mask,
# -> 1114                 xticklabels=xtl, yticklabels=ytl, **kws)
#    1115
#    1116         ytl = self.ax_heatmap.get_yticklabels()
#
# ~\Anaconda3\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     526     if square:
#     527         ax.set_aspect("equal")
# --> 528     plotter.plot(ax, cbar_ax, kwargs)
#     529     return ax
#     530
#
# ~\Anaconda3\lib\site-packages\seaborn\matrix.py in plot(self, ax, cax, kws)
#     282         # Draw the heatmap
#     283         mesh = ax.pcolormesh(self.plot_data, vmin=self.vmin, vmax=self.vmax,
# --> 284                              cmap=self.cmap, **kws)
#     285
#     286         # Set the axis limits
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in pcolormesh(self, alpha, norm, cmap, vmin, vmax, shading, antialiased, *args, **kwargs)
#    6169         collection = mcoll.QuadMesh(Nx - 1, Ny - 1, coords,
#    6170                                     antialiased=antialiased, shading=shading,
# -> 6171                                     **kwargs)
#    6172         collection.set_alpha(alpha)
#    6173         collection.set_array(C)
#
# ~\Anaconda3\lib\site-packages\matplotlib\collections.py in __init__(self, meshWidth, meshHeight, coordinates, antialiased, shading, **kwargs)
#    1910     def __init__(self, meshWidth, meshHeight, coordinates,
#    1911                  antialiased=True, shading='flat', **kwargs):
# -> 1912         Collection.__init__(self, **kwargs)
#    1913         self._meshWidth = meshWidth
#    1914         self._meshHeight = meshHeight
#
# ~\Anaconda3\lib\site-packages\matplotlib\collections.py in __init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, offset_position, zorder, **kwargs)
#     160
#     161         self._path_effects = None
# --> 162         self.update(kwargs)
#     163         self._paths = None
#     164
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
# --> 974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#     976         if len(ret):
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in <listcomp>(.0)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
# --> 974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#     976         if len(ret):
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in _update_property(self, k, v)
#     968                 if not callable(func):
#     969                     raise AttributeError('{!r} object has no property {!r}'
# --> 970                                          .format(type(self).__name__, k))
#     971                 return func(v)
#     972
#
# AttributeError: 'QuadMesh' object has no property 'camp'

# %%
sns.heatmap(comparison, annot=True)

# %%
sns.heatmap(comparison, cmap="YlGnBu")
